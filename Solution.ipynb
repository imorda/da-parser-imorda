# %%
import pandas as pd

# %%
df = pd.read_csv('data/result.csv', index_col=[0])

df
# Out:
#                               name body_type modification_name  price_min  \
# 0            Nissan Gloria X (Y33)     Седан            2.0 AT         -1
# 1            Nissan Gloria X (Y33)     Седан            2.5 AT     230000
# 2            Nissan Gloria X (Y33)     Седан            2.5 AT         -1
# 3            Nissan Gloria X (Y33)     Седан            3.0 AT         -1
# 4            Nissan Gloria X (Y33)     Седан            3.0 AT         -1
# ...                            ...       ...               ...        ...
# 58279  Toyota Avensis I Рестайлинг   Лифтбек            2.0 AT         -1
# 58280            Toyota Avensis II     Седан            2.2 MT         -1
# 58281            Toyota Avensis II   Лифтбек            1.8 AT         -1
# 58282            Toyota Avensis II     Седан            2.2 MT         -1
# 58283  Toyota Avensis I Рестайлинг   Лифтбек            2.0 AT         -1
#
#        price_max country classe  doors_count  seats_count steering_wheel_side  \
# 0             -1  Япония      E            4            5              Правый
# 1         230000  Япония      E            4            5              Правый
# 2             -1  Япония      E            4            5              Правый
# 3             -1  Япония      E            4            5              Правый
# 4             -1  Япония      E            4            5              Правый
# ...          ...     ...    ...          ...          ...                 ...
# 58279         -1  Япония      D            5            5        Левый/Правый
# 58280         -1  Япония      D            4            5        Левый/Правый
# 58281         -1  Япония      D            5            5        Левый/Правый
# 58282         -1  Япония      D            4            5        Левый/Правый
# 58283         -1  Япония      D            5            5        Левый/Правый
#
#        ... engine_max_power_rpm engine_max_torque engine_max_torque_rpm  \
# 0      ...                 6000               167                  3200
# 1      ...                 6400               235                  4000
# 2      ...                 6400               275                  4800
# 3      ...                 5200               248                  3200
# 4      ...                 6000               368                  3600
# ...    ...                  ...               ...                   ...
# 58279  ...                 5700               200                  4000
# 58280  ...                 3600               310                  2000
# 58281  ...                 6000               170                  4200
# 58282  ...                 3600               310                  2000
# 58283  ...                 5400               178                  4400
#
#       engine_cylinders_position  engine_cylinders_count  \
# 0                    V-образное                       6
# 1                    V-образное                       6
# 2                        рядное                       6
# 3                    V-образное                       6
# 4                    V-образное                       6
# ...                         ...                     ...
# 58279                    рядное                       4
# 58280                    рядное                       4
# 58281                    рядное                       4
# 58282                    рядное                       4
# 58283                    рядное                       4
#
#        engine_valves_per_cylinder                     engine_intake_type  \
# 0                              -1  распределенный впрыск (многоточечный)
# 1                               4  распределенный впрыск (многоточечный)
# 2                               4  распределенный впрыск (многоточечный)
# 3                               2  распределенный впрыск (многоточечный)
# 4                               4       непосредственный впрыск (прямой)
# ...                           ...                                    ...
# 58279                           4  распределенный впрыск (многоточечный)
# 58280                           4                   Common rail (Дизель)
# 58281                           4  распределенный впрыск (многоточечный)
# 58282                           4                   Common rail (Дизель)
# 58283                           4  распределенный впрыск (многоточечный)
#
#        engine_compression  engine_cylinder_diameter  engine_piston_stroke
# 0                    10.0                      78.0                  70.0
# 1                    10.0                      85.0                  73.0
# 2                    10.0                      86.0                  72.0
# 3                     9.0                      87.0                  83.0
# 4                     9.0                      87.0                  83.0
# ...                   ...                       ...                   ...
# 58279                 9.0                      86.0                  86.0
# 58280                16.8                      86.0                  96.0
# 58281                10.0                      79.0                  91.5
# 58282                16.8                      86.0                  96.0
# 58283                 9.8                      86.0                  86.0
#
# [58284 rows x 53 columns]

# %%
df['body_type'] = pd.Categorical(df['body_type'])
df['country'] = pd.Categorical(df['country'])
df['classe'] = pd.Categorical(df['classe'])
df['steering_wheel_side'] = pd.Categorical(df['steering_wheel_side'])
df['front_suspension_type'] = pd.Categorical(df['front_suspension_type'])
df['rear_suspension_type'] = pd.Categorical(df['rear_suspension_type'])
df['front_brakes_type'] = pd.Categorical(df['front_brakes_type'])
df['rear_brakes_type'] = pd.Categorical(df['rear_brakes_type'])
df['fuel_type'] = pd.Categorical(df['fuel_type'])
df['emission_class'] = pd.Categorical(df['emission_class'])
df['gearbox_type'] = pd.Categorical(df['gearbox_type'])
df['drive_type'] = pd.Categorical(df['drive_type'])
df['engine_type'] = pd.Categorical(df['engine_type'])
df['engine_position'] = pd.Categorical(df['engine_position'])
df['engine_rotation'] = pd.Categorical(df['engine_rotation'])
df['engine_turbo_type'] = pd.Categorical(df['engine_turbo_type'])
df['engine_cylinders_position'] = pd.Categorical(df['engine_cylinders_position'])
df['engine_intake_type'] = pd.Categorical(df['engine_intake_type'])

df.dtypes
# Out:
# name                            object
# body_type                     category
# modification_name               object
# price_min                        int64
# price_max                        int64
# country                       category
# classe                        category
# doors_count                      int64
# seats_count                      int64
# steering_wheel_side           category
# front_suspension_type         category
# rear_suspension_type          category
# front_brakes_type             category
# rear_brakes_type              category
# length                           int64
# width                            int64
# height                           int64
# wheelbase                        int64
# clearance                        int64
# front_track                      int64
# rear_track                       int64
# max_speed                        int64
# zero_to_100                    float64
# fuel_consumption_city          float64
# fuel_consumption_road          float64
# fuel_consumption_mixed         float64
# fuel_type                     category
# emission_class                category
# trunk_volume_min                 int64
# trunk_volume_max                 int64
# fuel_tank_volume                 int64
# equipped_weight                  int64
# max_weight                       int64
# gearbox_type                  category
# gear_count                       int64
# drive_type                    category
# engine_type                   category
# engine_position               category
# engine_rotation               category
# engine_displacement              int64
# engine_turbo_type             category
# engine_max_horsepower            int64
# engine_max_power_kilowatt      float64
# engine_max_power_rpm             int64
# engine_max_torque                int64
# engine_max_torque_rpm            int64
# engine_cylinders_position     category
# engine_cylinders_count           int64
# engine_valves_per_cylinder       int64
# engine_intake_type            category
# engine_compression             float64
# engine_cylinder_diameter       float64
# engine_piston_stroke           float64
# dtype: object

# %%
df
# Out:
#                               name body_type modification_name  price_min  \
# 0            Nissan Gloria X (Y33)     Седан            2.0 AT         -1
# 1            Nissan Gloria X (Y33)     Седан            2.5 AT     230000
# 2            Nissan Gloria X (Y33)     Седан            2.5 AT         -1
# 3            Nissan Gloria X (Y33)     Седан            3.0 AT         -1
# 4            Nissan Gloria X (Y33)     Седан            3.0 AT         -1
# ...                            ...       ...               ...        ...
# 58279  Toyota Avensis I Рестайлинг   Лифтбек            2.0 AT         -1
# 58280            Toyota Avensis II     Седан            2.2 MT         -1
# 58281            Toyota Avensis II   Лифтбек            1.8 AT         -1
# 58282            Toyota Avensis II     Седан            2.2 MT         -1
# 58283  Toyota Avensis I Рестайлинг   Лифтбек            2.0 AT         -1
#
#        price_max country classe  doors_count  seats_count steering_wheel_side  \
# 0             -1  Япония      E            4            5              Правый
# 1         230000  Япония      E            4            5              Правый
# 2             -1  Япония      E            4            5              Правый
# 3             -1  Япония      E            4            5              Правый
# 4             -1  Япония      E            4            5              Правый
# ...          ...     ...    ...          ...          ...                 ...
# 58279         -1  Япония      D            5            5        Левый/Правый
# 58280         -1  Япония      D            4            5        Левый/Правый
# 58281         -1  Япония      D            5            5        Левый/Правый
# 58282         -1  Япония      D            4            5        Левый/Правый
# 58283         -1  Япония      D            5            5        Левый/Правый
#
#        ... engine_max_power_rpm engine_max_torque engine_max_torque_rpm  \
# 0      ...                 6000               167                  3200
# 1      ...                 6400               235                  4000
# 2      ...                 6400               275                  4800
# 3      ...                 5200               248                  3200
# 4      ...                 6000               368                  3600
# ...    ...                  ...               ...                   ...
# 58279  ...                 5700               200                  4000
# 58280  ...                 3600               310                  2000
# 58281  ...                 6000               170                  4200
# 58282  ...                 3600               310                  2000
# 58283  ...                 5400               178                  4400
#
#       engine_cylinders_position  engine_cylinders_count  \
# 0                    V-образное                       6
# 1                    V-образное                       6
# 2                        рядное                       6
# 3                    V-образное                       6
# 4                    V-образное                       6
# ...                         ...                     ...
# 58279                    рядное                       4
# 58280                    рядное                       4
# 58281                    рядное                       4
# 58282                    рядное                       4
# 58283                    рядное                       4
#
#        engine_valves_per_cylinder                     engine_intake_type  \
# 0                              -1  распределенный впрыск (многоточечный)
# 1                               4  распределенный впрыск (многоточечный)
# 2                               4  распределенный впрыск (многоточечный)
# 3                               2  распределенный впрыск (многоточечный)
# 4                               4       непосредственный впрыск (прямой)
# ...                           ...                                    ...
# 58279                           4  распределенный впрыск (многоточечный)
# 58280                           4                   Common rail (Дизель)
# 58281                           4  распределенный впрыск (многоточечный)
# 58282                           4                   Common rail (Дизель)
# 58283                           4  распределенный впрыск (многоточечный)
#
#        engine_compression  engine_cylinder_diameter  engine_piston_stroke
# 0                    10.0                      78.0                  70.0
# 1                    10.0                      85.0                  73.0
# 2                    10.0                      86.0                  72.0
# 3                     9.0                      87.0                  83.0
# 4                     9.0                      87.0                  83.0
# ...                   ...                       ...                   ...
# 58279                 9.0                      86.0                  86.0
# 58280                16.8                      86.0                  96.0
# 58281                10.0                      79.0                  91.5
# 58282                16.8                      86.0                  96.0
# 58283                 9.8                      86.0                  86.0
#
# [58284 rows x 53 columns]

# %%
df.body_type.cat.categories
# Out:
# Index(['Внедорожник 3 дв.', 'Внедорожник 3 дв. 71', 'Внедорожник 3 дв. 78',
#        'Внедорожник 3 дв. 90', 'Внедорожник 3 дв. Bronto',
#        'Внедорожник 3 дв. SV Coupe', 'Внедорожник 3 дв. Sport',
#        'Внедорожник 3 дв. Urban', 'Внедорожник 3 дв. Рысь',
#        'Внедорожник 3 дв. Тарзан',
#        ...
#        'Хэтчбек 5 дв. Sportback', 'Хэтчбек 5 дв. Stepway',
#        'Хэтчбек 5 дв. Wide', 'Хэтчбек 5 дв. X', 'Хэтчбек 5 дв. X-Line',
#        'Хэтчбек 5 дв. X-line', 'Хэтчбек 5 дв. XT', 'Хэтчбек 5 дв. XV',
#        'Хэтчбек 5 дв. citycarver', 'Хэтчбек 5 дв. Тарзан'],
#       dtype='object', length=355)

# %%
df.country.cat.categories
# Out:
# Index(['Великобритания', 'Германия', 'Иран', 'Испания', 'Италия', 'Китай',
#        'Россия', 'США', 'Узбекистан', 'Украина', 'Франция', 'Чехия', 'Швеция',
#        'Южная Корея', 'Япония'],
#       dtype='object')

# %%
df.classe.cat.categories
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'J', 'M', 'S', 'undefined'], dtype='object')

# %%
df.steering_wheel_side.cat.categories
# Out:
# Index(['Левый', 'Левый/Правый', 'Правый'], dtype='object')

# %%
df[df.name.str.contains("Audi A6") & df.name.str.contains("C6") & df.modification_name.str.contains("3.0") & df.engine_intake_type.str.contains('распределенный')]
# Out:
#                    name        body_type modification_name  price_min  \
# 26899  Audi A6 III (C6)  Универсал 5 дв.           3.0 CVT         -1
# 26911  Audi A6 III (C6)  Универсал 5 дв.            3.0 AT         -1
# 27116  Audi A6 III (C6)            Седан            3.0 MT         -1
# 27123  Audi A6 III (C6)            Седан            3.0 AT         -1
# 27131  Audi A6 III (C6)            Седан           3.0 CVT         -1
#
#        price_max   country classe  doors_count  seats_count  \
# 26899         -1  Германия      E            5            5
# 26911         -1  Германия      E            5            5
# 27116         -1  Германия      E            4            5
# 27123         -1  Германия      E            4            5
# 27131         -1  Германия      E            4            5
#
#       steering_wheel_side  ... engine_max_power_rpm engine_max_torque  \
# 26899               Левый  ...                 6300               290
# 26911               Левый  ...                 6300               290
# 27116               Левый  ...                 6300               290
# 27123               Левый  ...                 6300               290
# 27131               Левый  ...                 6300               290
#
#       engine_max_torque_rpm engine_cylinders_position  engine_cylinders_count  \
# 26899                  3200                V-образное                       6
# 26911                  3200                V-образное                       6
# 27116                  3200                V-образное                       6
# 27123                  3200                V-образное                       6
# 27131                  3200                V-образное                       6
#
#        engine_valves_per_cylinder                     engine_intake_type  \
# 26899                           5  распределенный впрыск (многоточечный)
# 26911                           5  распределенный впрыск (многоточечный)
# 27116                           5  распределенный впрыск (многоточечный)
# 27123                           5  распределенный впрыск (многоточечный)
# 27131                           5  распределенный впрыск (многоточечный)
#
#        engine_compression  engine_cylinder_diameter  engine_piston_stroke
# 26899                10.5                      82.5                  92.8
# 26911                10.5                      82.5                  92.8
# 27116                10.5                      82.5                  92.8
# 27123                10.5                      82.5                  92.8
# 27131                10.5                      82.5                  92.8
#
# [5 rows x 53 columns]

# %%
df[df.name.str.contains("Ford Sierra") & df.modification_name.str.contains("1.8")]
# Out:
#                            name        body_type modification_name  price_min  \
# 38923  Ford Sierra I Рестайлинг    Хэтчбек 3 дв.            1.8 MT         -1
# 38924  Ford Sierra I Рестайлинг    Хэтчбек 3 дв.            1.8 AT         -1
# 38925  Ford Sierra I Рестайлинг    Хэтчбек 3 дв.            1.8 MT         -1
# 38927  Ford Sierra I Рестайлинг    Хэтчбек 3 дв.            1.8 MT         -1
# 38930  Ford Sierra I Рестайлинг    Хэтчбек 3 дв.            1.8 AT         -1
# 38947  Ford Sierra I Рестайлинг    Хэтчбек 3 дв.            1.8 AT         -1
# 38948  Ford Sierra I Рестайлинг    Хэтчбек 3 дв.            1.8 AT         -1
# 38951  Ford Sierra I Рестайлинг    Хэтчбек 3 дв.            1.8 MT         -1
# 38954  Ford Sierra I Рестайлинг    Хэтчбек 5 дв.            1.8 MT         -1
# 38956  Ford Sierra I Рестайлинг    Хэтчбек 5 дв.            1.8 MT         -1
# 38958  Ford Sierra I Рестайлинг    Хэтчбек 5 дв.            1.8 AT         -1
# 38960  Ford Sierra I Рестайлинг    Хэтчбек 5 дв.            1.8 MT         -1
# 38963  Ford Sierra I Рестайлинг    Хэтчбек 5 дв.            1.8 AT         -1
# 38971  Ford Sierra I Рестайлинг    Хэтчбек 5 дв.            1.8 AT         -1
# 38976  Ford Sierra I Рестайлинг    Хэтчбек 5 дв.            1.8 AT         -1
# 38978  Ford Sierra I Рестайлинг    Хэтчбек 5 дв.            1.8 MT         -1
# 39004  Ford Sierra I Рестайлинг  Универсал 5 дв.            1.8 MT         -1
# 39006  Ford Sierra I Рестайлинг  Универсал 5 дв.            1.8 MT         -1
# 39007  Ford Sierra I Рестайлинг  Универсал 5 дв.            1.8 AT         -1
# 39008  Ford Sierra I Рестайлинг  Универсал 5 дв.            1.8 AT         -1
# 39009  Ford Sierra I Рестайлинг  Универсал 5 дв.            1.8 MT         -1
# 39010  Ford Sierra I Рестайлинг  Универсал 5 дв.            1.8 AT         -1
# 39030             Ford Sierra I  Универсал 5 дв.            1.8 MT         -1
# 39032  Ford Sierra I Рестайлинг  Универсал 5 дв.            1.8 MT         -1
# 39040             Ford Sierra I  Универсал 5 дв.            1.8 AT         -1
# 39045             Ford Sierra I    Хэтчбек 5 дв.            1.8 MT         -1
# 39052             Ford Sierra I    Хэтчбек 5 дв.            1.8 AT         -1
# 39070             Ford Sierra I    Хэтчбек 3 дв.            1.8 MT         -1
# 39076             Ford Sierra I    Хэтчбек 3 дв.            1.8 AT         -1
# 39145  Ford Sierra I Рестайлинг            Седан            1.8 MT     125000
# 39146  Ford Sierra I Рестайлинг            Седан            1.8 AT     125000
# 39147  Ford Sierra I Рестайлинг            Седан            1.8 AT     125000
# 39150  Ford Sierra I Рестайлинг            Седан            1.8 MT     125000
# 39154  Ford Sierra I Рестайлинг            Седан            1.8 MT     125000
# 39166  Ford Sierra I Рестайлинг            Седан            1.8 AT     125000
# 39197  Ford Sierra I Рестайлинг            Седан            1.8 MT         -1
#
#        price_max country classe  doors_count  seats_count steering_wheel_side  \
# 38923         -1     США      D            3            5               Левый
# 38924         -1     США      D            3            5               Левый
# 38925         -1     США      D            3            5               Левый
# 38927         -1     США      D            3            5               Левый
# 38930         -1     США      D            3            5               Левый
# 38947         -1     США      D            3            5               Левый
# 38948         -1     США      D            3            5               Левый
# 38951         -1     США      D            3            5               Левый
# 38954         -1     США      D            5            5               Левый
# 38956         -1     США      D            5            5               Левый
# 38958         -1     США      D            5            5               Левый
# 38960         -1     США      D            5            5               Левый
# 38963         -1     США      D            5            5               Левый
# 38971         -1     США      D            5            5               Левый
# 38976         -1     США      D            5            5               Левый
# 38978         -1     США      D            5            5               Левый
# 39004         -1     США      D            5            5               Левый
# 39006         -1     США      D            5            5               Левый
# 39007         -1     США      D            5            5               Левый
# 39008         -1     США      D            5            5               Левый
# 39009         -1     США      D            5            5               Левый
# 39010         -1     США      D            5            5               Левый
# 39030         -1     США      D            5            5               Левый
# 39032         -1     США      D            5            5               Левый
# 39040         -1     США      D            5            5               Левый
# 39045         -1     США      D            5            5               Левый
# 39052         -1     США      D            5            5               Левый
# 39070         -1     США      D            3            5               Левый
# 39076         -1     США      D            3            5               Левый
# 39145     125000     США      D            4            5               Левый
# 39146     125000     США      D            4            5               Левый
# 39147     125000     США      D            4            5               Левый
# 39150     125000     США      D            4            5               Левый
# 39154     125000     США      D            4            5               Левый
# 39166     125000     США      D            4            5               Левый
# 39197         -1     США      D            4            5               Левый
#
#        ... engine_max_power_rpm engine_max_torque engine_max_torque_rpm  \
# 38923  ...                 5400               140                  3500
# 38924  ...                   -1                -1                    -1
# 38925  ...                 5400               120                  3500
# 38927  ...                   -1                -1                    -1
# 38930  ...                 5400               140                  3500
# 38947  ...                   -1                -1                    -1
# 38948  ...                 4000               175                  1800
# 38951  ...                 4000               175                  1800
# 38954  ...                   -1                -1                    -1
# 38956  ...                 5400               120                  3500
# 38958  ...                   -1                -1                    -1
# 38960  ...                 5400               140                  3500
# 38963  ...                 5400               140                  3500
# 38971  ...                   -1                -1                    -1
# 38976  ...                 4000               175                  1800
# 38978  ...                 4000               175                  1800
# 39004  ...                 5400               120                  3500
# 39006  ...                   -1                -1                    -1
# 39007  ...                 5400               140                  3500
# 39008  ...                   -1                -1                    -1
# 39009  ...                 5400               140                  3500
# 39010  ...                   -1                -1                    -1
# 39030  ...                 5400               140                  3500
# 39032  ...                   -1                -1                    -1
# 39040  ...                 5400               140                  3500
# 39045  ...                 5400               140                  3500
# 39052  ...                 5400               140                  3500
# 39070  ...                 5400               140                  3500
# 39076  ...                 5400               140                  3500
# 39145  ...                 5400               120                  3500
# 39146  ...                   -1                -1                    -1
# 39147  ...                 5400               140                  3500
# 39150  ...                 5400               140                  3500
# 39154  ...                   -1                -1                    -1
# 39166  ...                   -1                -1                    -1
# 39197  ...                   -1                -1                    -1
#
#       engine_cylinders_position  engine_cylinders_count  \
# 38923                    рядное                       4
# 38924                    рядное                       4
# 38925                    рядное                       4
# 38927                    рядное                       4
# 38930                    рядное                       4
# 38947                    рядное                       4
# 38948                    рядное                       4
# 38951                    рядное                       4
# 38954                    рядное                       4
# 38956                    рядное                       4
# 38958                    рядное                       4
# 38960                    рядное                       4
# 38963                    рядное                       4
# 38971                    рядное                       4
# 38976                    рядное                       4
# 38978                    рядное                       4
# 39004                    рядное                       4
# 39006                    рядное                       4
# 39007                    рядное                       4
# 39008                    рядное                       4
# 39009                    рядное                       4
# 39010                    рядное                       4
# 39030                    рядное                       4
# 39032                    рядное                       4
# 39040                    рядное                       4
# 39045                    рядное                       4
# 39052                    рядное                       4
# 39070                    рядное                       4
# 39076                    рядное                       4
# 39145                    рядное                       4
# 39146                    рядное                       4
# 39147                    рядное                       4
# 39150                    рядное                       4
# 39154                    рядное                       4
# 39166                    рядное                       4
# 39197                    рядное                       4
#
#        engine_valves_per_cylinder  engine_intake_type  engine_compression  \
# 38923                           2          карбюратор                 9.5
# 38924                           2          карбюратор                 9.5
# 38925                           2          карбюратор                 9.5
# 38927                           2          карбюратор                 9.5
# 38930                           2          карбюратор                 9.5
# 38947                           2          карбюратор                 9.5
# 38948                           2       ТНВД (Дизель)                19.4
# 38951                           2       ТНВД (Дизель)                19.4
# 38954                           2          карбюратор                 9.5
# 38956                           2          карбюратор                 9.5
# 38958                           2          карбюратор                 9.5
# 38960                           2          карбюратор                 9.5
# 38963                           2          карбюратор                 9.5
# 38971                           2          карбюратор                 9.5
# 38976                           2       ТНВД (Дизель)                19.4
# 38978                           2       ТНВД (Дизель)                19.4
# 39004                           2          карбюратор                 9.5
# 39006                           2          карбюратор                 9.5
# 39007                           2          карбюратор                 9.5
# 39008                           2          карбюратор                 9.5
# 39009                           2          карбюратор                 9.5
# 39010                           2          карбюратор                 9.5
# 39030                           2          карбюратор                 9.5
# 39032                           2       ТНВД (Дизель)                21.5
# 39040                           2          карбюратор                 9.5
# 39045                           2          карбюратор                 9.5
# 39052                           2          карбюратор                 9.5
# 39070                           2          карбюратор                 9.5
# 39076                           2          карбюратор                 9.5
# 39145                           2          карбюратор                 9.5
# 39146                           2          карбюратор                 9.5
# 39147                           2          карбюратор                 9.5
# 39150                           2          карбюратор                 9.5
# 39154                           2          карбюратор                 9.5
# 39166                           2          карбюратор                 9.5
# 39197                           2       ТНВД (Дизель)                21.5
#
#        engine_cylinder_diameter  engine_piston_stroke
# 38923                     86.20                 76.95
# 38924                     86.20                 76.95
# 38925                     86.20                 77.00
# 38927                     86.20                 76.95
# 38930                     86.20                 76.95
# 38947                     86.20                 76.95
# 38948                     82.50                 82.00
# 38951                     82.50                 82.00
# 38954                     86.20                 76.95
# 38956                     86.20                 77.00
# 38958                     86.20                 76.95
# 38960                     86.20                 76.95
# 38963                     86.20                 77.00
# 38971                     86.20                 76.95
# 38976                     82.50                 82.00
# 38978                     82.50                 82.00
# 39004                     86.20                 77.00
# 39006                     86.20                 76.95
# 39007                     86.20                 76.95
# 39008                     86.20                 76.95
# 39009                     86.20                 76.95
# 39010                     86.20                 76.95
# 39030                     86.20                 76.95
# 39032                     82.50                 82.00
# 39040                     86.20                 76.95
# 39045                     86.20                 76.95
# 39052                     86.20                 76.95
# 39070                     86.20                 76.95
# 39076                     86.20                 76.95
# 39145                     86.20                 77.00
# 39146                     86.20                 76.95
# 39147                     86.20                 77.00
# 39150                     86.20                 76.95
# 39154                     86.20                 76.95
# 39166                     86.20                 76.95
# 39197                     82.25                 82.00
#
# [36 rows x 53 columns]
